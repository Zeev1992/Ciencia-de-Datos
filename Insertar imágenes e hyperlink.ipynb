# %% [markdown]
# # __INSERTAR IMÁGENES__
# ## Pasos para insertar imágenes en J. Notebook

# %% [markdown]
# 1. Abrimos una celda markdown
# 2. abrimos la carpeta donde esta la imagen
# 3. Arrastramos la imagen a la celda
# 4. crea la línea de comando:
# ![linea1.png](attachment:linea1.png)
# 4. damos clic a run

# %% [markdown]
# ![anaconda.png](attachment:anaconda.png)

# %% [markdown]
# # __INSERTAR UN LINK__
# ## Pasos para insertar un hyperlink en J. Notebook

# %% [markdown]
# 1. abra una celda markdown
# 2. copie la url de la página web
# 3. esciba el nombre de la página: ejemplo [chatgpt]
# 4. Abre paréntesis y pega el link
# 5. cierra paréntesis.
# 6. quedaría así: ![l%C3%ADnea2.png](attachment:l%C3%ADnea2.png)

# %% [markdown]
# [dele clic a: ChatGpt](https://chat.openai.com/)
